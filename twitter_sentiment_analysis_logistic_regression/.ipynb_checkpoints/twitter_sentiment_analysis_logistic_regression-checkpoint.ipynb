# %% [markdown]
# # Twitter sentiment analysis using logistic regression

# %% [markdown]
# Initial data transformation

# %%
import numpy as np # linear algebra
import pandas as pd # data processing
pd.options.mode.chained_assignment = None
import os #File location
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

from wordcloud import WordCloud #Word visualization
import matplotlib.pyplot as plt #Plotting properties
import seaborn as sns #Plotting properties
from sklearn.feature_extraction.text import CountVectorizer #Data transformation
from sklearn.model_selection import train_test_split #Data testing
from sklearn.linear_model import LogisticRegression #Prediction Model
from sklearn.metrics import accuracy_score #Comparison between real and predicted
from xgboost import XGBClassifier
from sklearn.preprocessing import LabelEncoder #Variable encoding and decoding for XGBoost
import re #Regular expressions
import nltk
from nltk import word_tokenize
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ADMIN\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
#Validation dataset
val=pd.read_csv("twitter_validation.csv", header=None)
#Full dataset for Train-Test
train=pd.read_csv("twitter_training.csv", header=None)

# %%
val
# Out:
#         0                    1           2  \
# 0    3364             Facebook  Irrelevant
# 1     352               Amazon     Neutral
# 2    8312            Microsoft    Negative
# 3    4371                CS-GO    Negative
# 4    4433               Google     Neutral
# ..    ...                  ...         ...
# 995  4891  GrandTheftAuto(GTA)  Irrelevant
# 996  4359                CS-GO  Irrelevant
# 997  2652          Borderlands    Positive
# 998  8069            Microsoft    Positive
# 999  6960      johnson&johnson     Neutral
#
#                                                      3
# 0    I mentioned on Facebook that I was struggling ...
# 1    BBC News - Amazon boss Jeff Bezos rejects clai...
# 2    @Microsoft Why do I pay for WORD when it funct...
# 3    CSGO matchmaking is so full of closet hacking,...
# 4    Now the President is slapping Americans in the...
# ..                                                 ...
# 995  ⭐️ Toronto is the arts and culture capital of ...
# 996  tHIS IS ACTUALLY A GOOD MOVE TOT BRING MORE VI...
# 997  Today sucked so it’s time to drink wine n play...
# 998  Bought a fraction of Microsoft today. Small wins.
# 999  Johnson & Johnson to stop selling talc baby po...
#
# [1000 rows x 4 columns]

# %%
train
# Out:
#           0            1         2  \
# 0      2401  Borderlands  Positive
# 1      2401  Borderlands  Positive
# 2      2401  Borderlands  Positive
# 3      2401  Borderlands  Positive
# 4      2401  Borderlands  Positive
# ...     ...          ...       ...
# 74677  9200       Nvidia  Positive
# 74678  9200       Nvidia  Positive
# 74679  9200       Nvidia  Positive
# 74680  9200       Nvidia  Positive
# 74681  9200       Nvidia  Positive
#
#                                                        3
# 0      im getting on borderlands and i will murder yo...
# 1      I am coming to the borders and I will kill you...
# 2      im getting on borderlands and i will kill you ...
# 3      im coming on borderlands and i will murder you...
# 4      im getting on borderlands 2 and i will murder ...
# ...                                                  ...
# 74677  Just realized that the Windows partition of my...
# 74678  Just realized that my Mac window partition is ...
# 74679  Just realized the windows partition of my Mac ...
# 74680  Just realized between the windows partition of...
# 74681  Just like the windows partition of my Mac is l...
#
# [74682 rows x 4 columns]

# %%
train.columns=['id','information','type','text']
train.head()
# Out:
#      id  information      type  \
# 0  2401  Borderlands  Positive
# 1  2401  Borderlands  Positive
# 2  2401  Borderlands  Positive
# 3  2401  Borderlands  Positive
# 4  2401  Borderlands  Positive
#
#                                                 text
# 0  im getting on borderlands and i will murder yo...
# 1  I am coming to the borders and I will kill you...
# 2  im getting on borderlands and i will kill you ...
# 3  im coming on borderlands and i will murder you...
# 4  im getting on borderlands 2 and i will murder ...

# %%
val.columns=['id','information','type','text']
val.head()
# Out:
#      id information        type  \
# 0  3364    Facebook  Irrelevant
# 1   352      Amazon     Neutral
# 2  8312   Microsoft    Negative
# 3  4371       CS-GO    Negative
# 4  4433      Google     Neutral
#
#                                                 text
# 0  I mentioned on Facebook that I was struggling ...
# 1  BBC News - Amazon boss Jeff Bezos rejects clai...
# 2  @Microsoft Why do I pay for WORD when it funct...
# 3  CSGO matchmaking is so full of closet hacking,...
# 4  Now the President is slapping Americans in the...

# %%
train_data = train
train_data
# Out:
#          id  information      type  \
# 0      2401  Borderlands  Positive
# 1      2401  Borderlands  Positive
# 2      2401  Borderlands  Positive
# 3      2401  Borderlands  Positive
# 4      2401  Borderlands  Positive
# ...     ...          ...       ...
# 74677  9200       Nvidia  Positive
# 74678  9200       Nvidia  Positive
# 74679  9200       Nvidia  Positive
# 74680  9200       Nvidia  Positive
# 74681  9200       Nvidia  Positive
#
#                                                     text
# 0      im getting on borderlands and i will murder yo...
# 1      I am coming to the borders and I will kill you...
# 2      im getting on borderlands and i will kill you ...
# 3      im coming on borderlands and i will murder you...
# 4      im getting on borderlands 2 and i will murder ...
# ...                                                  ...
# 74677  Just realized that the Windows partition of my...
# 74678  Just realized that my Mac window partition is ...
# 74679  Just realized the windows partition of my Mac ...
# 74680  Just realized between the windows partition of...
# 74681  Just like the windows partition of my Mac is l...
#
# [74682 rows x 4 columns]

# %%
val_data = val
val_data
# Out:
#        id          information        type  \
# 0    3364             Facebook  Irrelevant
# 1     352               Amazon     Neutral
# 2    8312            Microsoft    Negative
# 3    4371                CS-GO    Negative
# 4    4433               Google     Neutral
# ..    ...                  ...         ...
# 995  4891  GrandTheftAuto(GTA)  Irrelevant
# 996  4359                CS-GO  Irrelevant
# 997  2652          Borderlands    Positive
# 998  8069            Microsoft    Positive
# 999  6960      johnson&johnson     Neutral
#
#                                                   text
# 0    I mentioned on Facebook that I was struggling ...
# 1    BBC News - Amazon boss Jeff Bezos rejects clai...
# 2    @Microsoft Why do I pay for WORD when it funct...
# 3    CSGO matchmaking is so full of closet hacking,...
# 4    Now the President is slapping Americans in the...
# ..                                                 ...
# 995  ⭐️ Toronto is the arts and culture capital of ...
# 996  tHIS IS ACTUALLY A GOOD MOVE TOT BRING MORE VI...
# 997  Today sucked so it’s time to drink wine n play...
# 998  Bought a fraction of Microsoft today. Small wins.
# 999  Johnson & Johnson to stop selling talc baby po...
#
# [1000 rows x 4 columns]

# %%
#Text transformation
train_data["lower"]=train_data.text.str.lower() #lowercase
train_data["lower"]=[str(data) for data in train_data.lower] #converting all to string
train_data["lower"]=train_data.lower.apply(lambda x: re.sub('[^A-Za-z0-9 ]+', ' ', x)) #regex
val_data["lower"]=val_data.text.str.lower() #lowercase
val_data["lower"]=[str(data) for data in val_data.lower] #converting all to string
val_data["lower"]=val_data.lower.apply(lambda x: re.sub('[^A-Za-z0-9 ]+', ' ', x)) #regex to remove special characters

# %%
train_data.head()
# Out:
#      id  information      type  \
# 0  2401  Borderlands  Positive
# 1  2401  Borderlands  Positive
# 2  2401  Borderlands  Positive
# 3  2401  Borderlands  Positive
# 4  2401  Borderlands  Positive
#
#                                                 text  \
# 0  im getting on borderlands and i will murder yo...
# 1  I am coming to the borders and I will kill you...
# 2  im getting on borderlands and i will kill you ...
# 3  im coming on borderlands and i will murder you...
# 4  im getting on borderlands 2 and i will murder ...
#
#                                                lower
# 0  im getting on borderlands and i will murder yo...
# 1  i am coming to the borders and i will kill you...
# 2  im getting on borderlands and i will kill you ...
# 3  im coming on borderlands and i will murder you...
# 4  im getting on borderlands 2 and i will murder ...

# %%
word_cloud_text = ''.join(train_data[train_data["type"]=="Positive"].lower)
#Creation of wordcloud
wordcloud = WordCloud(
    max_font_size=100,
    max_words=100,
    background_color="pink",
    scale=10,
    width=800,
    height=800
).generate(word_cloud_text)
#Figure properties
plt.figure(figsize=(10,10))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
word_cloud_text = ''.join(train_data[train_data["type"]=="Negative"].lower)
#Creation of wordcloud
wordcloud = WordCloud(
    max_font_size=100,
    max_words=100,
    background_color="yellow",
    scale=10,
    width=800,
    height=800
).generate(word_cloud_text)
#Figure properties
plt.figure(figsize=(10,10))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
word_cloud_text = ''.join(train_data[train_data["type"]=="Irrelevant"].lower)
#Creation of wordcloud
wordcloud = WordCloud(
    max_font_size=100,
    max_words=100,
    background_color="red",
    scale=10,
    width=800,
    height=800
).generate(word_cloud_text)
#Figure properties
plt.figure(figsize=(10,10))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
word_cloud_text = ''.join(train_data[train_data["type"]=="Neutral"].lower)
#Creation of wordcloud
wordcloud = WordCloud(
    max_font_size=100,
    max_words=100,
    background_color="blue",
    scale=10,
    width=800,
    height=800
).generate(word_cloud_text)
#Figure properties
plt.figure(figsize=(10,10))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
#Count information per category
plot1=train.groupby(by=["information","type"]).count().reset_index()
plot1.head()
# Out:
#    information        type    id  text  lower
# 0       Amazon  Irrelevant   192   186    192
# 1       Amazon    Negative   576   575    576
# 2       Amazon     Neutral  1236  1207   1236
# 3       Amazon    Positive   312   308    312
# 4  ApexLegends  Irrelevant   192   192    192

# %%
#Figure of comparison per branch
plt.figure(figsize=(20,6))
sns.barplot(data=plot1,x="information",y="id",hue="type")
plt.xticks(rotation=90)
plt.xlabel("Brand")
plt.ylabel("Number of tweets")
plt.grid()
plt.title("Distribution of tweets per Branch and Type");

# %% [markdown]
# Text analysis

# %%
#Text splitting
tokens_text = [word_tokenize(str(word)) for word in train_data.lower]
#Unique word counter
tokens_counter = [item for sublist in tokens_text for item in sublist]
print("Number of tokens: ", len(set(tokens_counter)))
# Out:
# Number of tokens:  30436

# %%
tokens_text[1]
# Out:
# ['i',
#  'am',
#  'coming',
#  'to',
#  'the',
#  'borders',
#  'and',
#  'i',
#  'will',
#  'kill',
#  'you',
#  'all']

# %%
#Choosing english stopwords
stopwords_nltk = nltk.corpus.stopwords
stop_words = stopwords_nltk.words('english')
stop_words[:10]
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're"]

# %% [markdown]
# Logistic Regression model

# %%
#Initial Bag of Words
bow_counts = CountVectorizer(
    tokenizer=word_tokenize,
    stop_words=stop_words, #English Stopwords
    ngram_range=(1, 1) #analysis of one word
)

# %%
bow_counts, train_data
# Out:
# (CountVectorizer(ngram_range=(1, 4),
#                  tokenizer=<function word_tokenize at 0x000001C4F2862340>),
#           id  information      type  \
#  0      2401  Borderlands  Positive
#  1      2401  Borderlands  Positive
#  2      2401  Borderlands  Positive
#  3      2401  Borderlands  Positive
#  4      2401  Borderlands  Positive
#  ...     ...          ...       ...
#  74677  9200       Nvidia  Positive
#  74678  9200       Nvidia  Positive
#  74679  9200       Nvidia  Positive
#  74680  9200       Nvidia  Positive
#  74681  9200       Nvidia  Positive
#
#                                                      text  \
#  0      im getting on borderlands and i will murder yo...
#  1      I am coming to the borders and I will kill you...
#  2      im getting on borderlands and i will kill you ...
#  3      im coming on borderlands and i will murder you...
#  4      im getting on borderlands 2 and i will murder ...
#  ...                                                  ...
#  74677  Just realized that the Windows partition of my...
#  74678  Just realized that my Mac window partition is ...
#  74679  Just realized the windows partition of my Mac ...
#  74680  Just realized between the windows partition of...
#  74681  Just like the windows partition of my Mac is l...
#
#                                                     lower
#  0      im getting on borderlands and i will murder yo...
#  1      i am coming to the borders and i will kill you...
#  2      im getting on borderlands and i will kill you ...
#  3      im coming on borderlands and i will murder you...
#  4      im getting on borderlands 2 and i will murder ...
#  ...                                                  ...
#  74677  just realized that the windows partition of my...
#  74678  just realized that my mac window partition is ...
#  74679  just realized the windows partition of my mac ...
#  74680  just realized between the windows partition of...
#  74681  just like the windows partition of my mac is l...
#
#  [74682 rows x 5 columns])

# %%
reviews_train, reviews_test = train_test_split(train_data, test_size=0.2, random_state=0)

# %%
reviews_train, reviews_test
# Out:
# (          id                        information        type  \
#  27749   1178                     AssassinsCreed    Positive
#  22415   4236                              CS-GO     Neutral
#  44208  10395  PlayerUnknownsBattlegrounds(PUBG)    Positive
#  71737  11089               TomClancysGhostRecon    Negative
#  41144   1461                        Battlefield     Neutral
#  ...      ...                                ...         ...
#  21243   4037                              CS-GO    Positive
#  45891  11877                            Verizon     Neutral
#  42613  10111  PlayerUnknownsBattlegrounds(PUBG)  Irrelevant
#  43567  10279  PlayerUnknownsBattlegrounds(PUBG)  Irrelevant
#  68268   3691                      Cyberpunk2077    Negative
#
#                                                      text  \
#  27749  this d&d campaign is going super well so it's ...
#  22415  for CS:GO Player Jamppi Sues Finland Player 5 ...
#  44208  Good news! , pubg will unban in india . 🤑. 🤩. ...
#  71737  @ GhostRecon _ UK cannot be played because no ...
#  41144                  Russian bots become Battlefield 1
#  ...                                                  ...
#  21243  Help me win this free 2015:GO giveaway from Id...
#  45891  This fall as Facebook faces major criticism fo...
#  42613  @ PUBGMOBILE (my game ID 5176547049 and ORCpre...
#  43567  I just finished my 2nd Youtube video, I enjoy ...
#  68268  Can I please have sex with Johnny in this game...
#
#                                                     lower
#  27749  this d d campaign is going super well so it s ...
#  22415  for cs go player jamppi sues finland player 5 ...
#  44208  good news    pubg will unban in india        p...
#  71737    ghostrecon   uk cannot be played because no ...
#  41144                  russian bots become battlefield 1
#  ...                                                  ...
#  21243  help me win this free 2015 go giveaway from id...
#  45891  this fall as facebook faces major criticism fo...
#  42613    pubgmobile  my game id 5176547049 and orcpre...
#  43567  i just finished my 2nd youtube video  i enjoy ...
#  68268  can i please have sex with johnny in this game...
#
#  [59745 rows x 5 columns],
#            id             information        type  \
#  28696    537             ApexLegends     Neutral
#  51606  10459  RedDeadRedemption(RDR)     Neutral
#  19463  12532            WorldOfCraft    Positive
#  26251    907          AssassinsCreed    Positive
#  55871   2390              CallOfDuty    Negative
#  ...      ...                     ...         ...
#  26359    928          AssassinsCreed    Positive
#  73612   9009                  Nvidia     Neutral
#  32084   7506         LeagueOfLegends    Negative
#  70762  10921    TomClancysGhostRecon     Neutral
#  44869  11705                 Verizon  Irrelevant
#
#                                                      text  \
#  28696  plus, why does it not fucking probably matter ...
#  51606  This look like the starting scene of Red Dead ...
#  19463  Talking stocks an World of Warcraft in the AM ...
#  26251                         Clothes of the Brotherhood
#  55871  @Activision so the last update literally broke...
#  ...                                                  ...
#  26359                                  Enjoying the view
#  73612  NVIDIA's massive internal A100 CPU GPU core is...
#  32084  Don't forget that tpci works with t * ncent fo...
#  70762  . at vg247. com / 11 2020 / 02 / 16 25 / html ...
#  44869  Police foundations prop up over-militarized, o...
#
#                                                     lower
#  28696  plus  why does it not fucking probably matter ...
#  51606  this look like the starting scene of red dead ...
#  19463  talking stocks an world of warcraft in the am ...
#  26251                         clothes of the brotherhood
#  55871   activision so the last update literally broke...
#  ...                                                  ...
#  26359                                  enjoying the view
#  73612  nvidia s massive internal a100 cpu gpu core is...
#  32084  don t forget that tpci works with t   ncent fo...
#  70762    at vg247  com   11 2020   02   16 25   html ...
#  44869  police foundations prop up over militarized  o...
#
#  [14937 rows x 5 columns])

# %%
bow_counts
# Out:
# CountVectorizer(ngram_range=(1, 4),
#                 tokenizer=<function word_tokenize at 0x000001C4F2862340>)

# %%
X_train_bow = bow_counts.fit_transform(reviews_train.lower)
X_test_bow = bow_counts.transform(reviews_test.lower)
# Out:
# C:\Users\ADMIN\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\feature_extraction\text.py:521: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(

# %%
X_train_bow
X_test_bow
# Out:
# <14937x28993 sparse matrix of type '<class 'numpy.int64'>'
# 	with 161222 stored elements in Compressed Sparse Row format>

# %%
y_train_bow = reviews_train['type']
y_test_bow = reviews_test['type']

# %%
y_test_bow.value_counts() / y_test_bow.shape[0]
# Out:
# type
# Negative      0.299190
# Positive      0.282252
# Neutral       0.245632
# Irrelevant    0.172926
# Name: count, dtype: float64

# %%
X_train_bow
X_test_bow
y_train_bow
y_test_bow
# Out:
# 28696       Neutral
# 51606       Neutral
# 19463      Positive
# 26251      Positive
# 55871      Negative
#             ...
# 26359      Positive
# 73612       Neutral
# 32084      Negative
# 70762       Neutral
# 44869    Irrelevant
# Name: type, Length: 14937, dtype: object

# %%
# Logistic regression
model1 = LogisticRegression(C=1, solver="liblinear",max_iter=200)
model1.fit(X_train_bow, y_train_bow)
# Prediction
test_pred = model1.predict(X_test_bow)
print("Accuracy: ", accuracy_score(y_test_bow, test_pred) * 100)
# Out:
# Accuracy:  81.50900448550578
# C:\Users\ADMIN\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\svm\_base.py:1235: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(

# %%
#Validation data
X_val_bow = bow_counts.transform(val_data.lower)
y_val_bow = val_data['type']

# %%
X_val_bow
# Out:
# <1000x28993 sparse matrix of type '<class 'numpy.int64'>'
# 	with 12913 stored elements in Compressed Sparse Row format>

# %%
y_val_bow
# Out:
# 0      Irrelevant
# 1         Neutral
# 2        Negative
# 3        Negative
# 4         Neutral
#           ...
# 995    Irrelevant
# 996    Irrelevant
# 997      Positive
# 998      Positive
# 999       Neutral
# Name: type, Length: 1000, dtype: object

# %%
val_res = model1.predict(X_val_bow)
print("Accuracy:",accuracy_score(y_val_bow,val_res)*100)
# Out:
# Accuracy: 91.7

# %%
#n-gram of 4 words
bow_counts = CountVectorizer(
    tokenizer=word_tokenize,
    ngram_range=(1,4)
)
#Data labeling
X_train_bow = bow_counts.fit_transform(reviews_train.lower)
X_test_bow = bow_counts.transform(reviews_test.lower)
X_val_bow = bow_counts.transform(val_data.lower)
# Out:
# C:\Users\ADMIN\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\feature_extraction\text.py:521: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(

# %%
X_train_bow
# Out:
# <59745x1427378 sparse matrix of type '<class 'numpy.int64'>'
# 	with 4142213 stored elements in Compressed Sparse Row format>

# %%
model2 = LogisticRegression(C=0.9, solver="liblinear",max_iter=1500)
# Logistic regression
model2.fit(X_train_bow, y_train_bow)
# Prediction
test_pred_2 = model2.predict(X_test_bow)
print("Accuracy: ", accuracy_score(y_test_bow, test_pred_2) * 100)
# Out:
# Accuracy:  90.79467095132891

# %%
y_val_bow = val_data['type']
Val_pred_2 = model2.predict(X_val_bow)
print("Accuracy: ", accuracy_score(y_val_bow, Val_pred_2) * 100)
# Out:
# Accuracy:  98.6

# %% [markdown]
# dmlc XG boost

# %%
y_train_bow
# Out:
# 27749      Positive
# 22415       Neutral
# 44208      Positive
# 71737      Negative
# 41144       Neutral
#             ...
# 21243      Positive
# 45891       Neutral
# 42613    Irrelevant
# 43567    Irrelevant
# 68268      Negative
# Name: type, Length: 59745, dtype: object

# %%
le = LabelEncoder()
y_train_bow_num = le.fit_transform(y_train_bow)
y_test_bow_num=le.transform(y_test_bow)
y_val_bow_num=le.transform(y_val_bow)

# %%
y_train_bow_num
# Out:
# array([3, 2, 3, ..., 0, 0, 1])

# %%
# %%time
XGB=XGBClassifier(objective="multi:softmax",n_estimators=1000,colsample_bytree=0.6, subsample=0.6)
XGB.fit(X_train_bow, y_train_bow_num)
# Prediction
test_pred_2 = XGB.predict(X_test_bow)
print("Accuracy: ", accuracy_score(y_test_bow_num, test_pred_2) * 100)
# Out:
# Accuracy:  84.88317600589141
# CPU times: total: 6h 18min 16s
# Wall time: 12h 43min 59s

# %%
y_val_bow = val_data['type']
Val_pred_2 = XGB.predict(X_val_bow)
print("Accuracy: ", accuracy_score(y_val_bow_num, Val_pred_2) * 100)
# Out:
# Accuracy:  96.0

# %%
test_pred_N = XGB.predict(X_train_bow)
print("Accuracy: ", accuracy_score(y_train_bow_num, test_pred_N) * 100)
# Out:
# Accuracy:  93.51242781822747

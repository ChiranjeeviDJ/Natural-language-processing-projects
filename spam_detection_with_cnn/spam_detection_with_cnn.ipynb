# %% [markdown]
# # Spam Detection with CNN

# %% [markdown]
# ## 1. Data Preprocessing

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.18.0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Dense, Input, GlobalMaxPooling1D
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Embedding
from tensorflow.keras.models import Model

# %%
df = pd.read_csv('spam.csv', encoding='ISO-8859-1') # encoding needed otherwise error raise, because some varchar exist

# %%
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
# drop garbage columns
df = df.drop(["Unnamed: 2", "Unnamed: 3", "Unnamed: 4"], axis=1)

# %%
df.head()
# Out:
#      v1                                                 v2
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
df.shape
# Out:
# (5572, 2)

# %%
# rename columns
df.columns = ['labels', 'data']

# %%
df.head()
# Out:
#   labels                                               data
# 0    ham  Go until jurong point, crazy.. Available only ...
# 1    ham                      Ok lar... Joking wif u oni...
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3    ham  U dun say so early hor... U c already then say...
# 4    ham  Nah I don't think he goes to usf, he lives aro...

# %%
# create binary labels (0 and 1)
df['b_labels'] = df['labels'].map({'ham': 0, 'spam': 1}) # create new column as 'b_labels'
y = df['b_labels'].values

# %%
y
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %%
df
# Out:
#      labels                                               data  b_labels
# 0       ham  Go until jurong point, crazy.. Available only ...         0
# 1       ham                      Ok lar... Joking wif u oni...         0
# 2      spam  Free entry in 2 a wkly comp to win FA Cup fina...         1
# 3       ham  U dun say so early hor... U c already then say...         0
# 4       ham  Nah I don't think he goes to usf, he lives aro...         0
# ...     ...                                                ...       ...
# 5567   spam  This is the 2nd time we have tried 2 contact u...         1
# 5568    ham              Will Ì_ b going to esplanade fr home?         0
# 5569    ham  Pity, * was in mood for that. So...any other s...         0
# 5570    ham  The guy did some bitching but I acted like i'd...         0
# 5571    ham                         Rofl. Its true to its name         0
#
# [5572 rows x 3 columns]

# %%
# split the data
x_train, x_test, y_train, y_test = train_test_split(df['data'], y, test_size=0.33)

# %%
# Convert sentences to sequences
max_vocab_size = 20000
tokenizer = Tokenizer(num_words=max_vocab_size)
tokenizer.fit_on_texts(x_train)
sequences_train = tokenizer.texts_to_sequences(x_train)
sequences_test = tokenizer.texts_to_sequences(x_test)

# %%
x_train[0]
# Out:
# 'Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...'

# %%
sequences_train[0]
# Out:
# [1, 94, 1244, 64, 4, 809, 507, 394, 223]

# %%
len(sequences_train[0])
# Out:
# 9

# %%
len(sequences_train[1])
# Out:
# 11

# %%
# Check word index mapping (to check the number of words in vocabulary)
word2idx = tokenizer.word_index
V = len(word2idx)
print('Total number of unique tokens are: %s' % V)
# Out:
# Total number of unique tokens are: 7142

# %%
print(word2idx)
# Out:
# {'i': 1, 'to': 2, 'you': 3, 'a': 4, 'the': 5, 'u': 6, 'and': 7, 'in': 8, 'is': 9, 'me': 10, 'my': 11, 'for': 12, 'your': 13, 'it': 14, 'of': 15, 'call': 16, 'have': 17, 'that': 18, 'on': 19, '2': 20, 'now': 21, 'are': 22, 'so': 23, 'not': 24, 'but': 25, 'at': 26, 'or': 27, 'can': 28, 'be': 29, 'do': 30, "i'm": 31, 'ur': 32, 'will': 33, 'just': 34, 'if': 35, 'with': 36, 'we': 37, 'get': 38, 'no': 39, 'this': 40, 'up': 41, '4': 42, 'go': 43, 'gt': 44, 'ok': 45, 'lt': 46, 'from': 47, 'when': 48, 'what': 49, 'how': 50, 'out': 51, 'know': 52, 'got': 53, 'free': 54, 'all': 55, 'then': 56, 'was': 57, 'good': 58, 'day': 59, 'like': 60, 'am': 61, 'come': 62, 'love': 63, 'its': 64, 'time': 65, 'only': 66, 'there': 67, 'send': 68, 'want': 69, 'he': 70, 'home': 71, 'about': 72, 'r': 73, 'text': 74, "i'll": 75, 'as': 76, 'n': 77, 'sorry': 78, 'da': 79, 'by': 80, 'one': 81, 'lor': 82, 'k': 83, 'going': 84, 'today': 85, 'txt': 86, 'back': 87, 'need': 88, 'she': 89, 'our': 90, 'hi': 91, 'see': 92, 'still': 93, 'dont': 94, 'any': 95, 'reply': 96, 'later': 97, 'they': 98, 'stop': 99, 'tell': 100, 'd': 101, 'her': 102, 'dear': 103, 'take': 104, 'phone': 105, "don't": 106, 'think': 107, 'please': 108, 'been': 109, 'hey': 110, 'here': 111, 'mobile': 112, 'new': 113, 'ì': 114, 'hope': 115, 'some': 116, 'has': 117, 'yes': 118, 'where': 119, 'much': 120, 'him': 121, 'msg': 122, 'well': 123, 'oh': 124, 'week': 125, 'too': 126, 'did': 127, '1': 128, 'wat': 129, 'way': 130, 'pls': 131, 'night': 132, 'claim': 133, 'ask': 134, 'already': 135, 'an': 136, 'work': 137, 'prize': 138, 'who': 139, 'number': 140, 'right': 141, 'great': 142, 'www': 143, 'had': 144, 'make': 145, 'message': 146, 'doing': 147, 'e': 148, 'tomorrow': 149, 'why': 150, 'really': 151, 'would': 152, 'should': 153, 'amp': 154, "it's": 155, 'more': 156, 'after': 157, '3': 158, 'c': 159, 'happy': 160, 'yeah': 161, 'give': 162, 'say': 163, 'said': 164, 'lol': 165, 'find': 166, 'cos': 167, 'care': 168, 'com': 169, 'meet': 170, 'very': 171, 'miss': 172, 'morning': 173, 'b': 174, 'something': 175, 'also': 176, 'let': 177, '150p': 178, 'thanks': 179, 'cash': 180, 'im': 181, 'sure': 182, 'again': 183, 'feel': 184, 'contact': 185, 'sent': 186, 'before': 187, 'were': 188, 'anything': 189, 't': 190, 'told': 191, 'life': 192, 'min': 193, 'won': 194, 'urgent': 195, 'per': 196, 'cant': 197, 'wait': 198, 'someone': 199, 'over': 200, 'babe': 201, 'around': 202, 'last': 203, 'uk': 204, 'them': 205, 'keep': 206, "i've": 207, 'win': 208, 'every': 209, '5': 210, 'nokia': 211, 'went': 212, 'pick': 213, 'first': 214, "that's": 215, 'gonna': 216, 'late': 217, 's': 218, 'hello': 219, 'off': 220, 'buy': 221, 'tonight': 222, 'us': 223, 'thing': 224, 'service': 225, 'dun': 226, 'down': 227, 'many': 228, 'could': 229, 'his': 230, 'money': 231, 'gud': 232, 'coming': 233, 'wan': 234, 'place': 235, 'name': 236, 'ya': 237, 'sleep': 238, 'holiday': 239, 'sms': 240, 'ìï': 241, 'getting': 242, 'which': 243, 'nice': 244, 'fine': 245, 'yet': 246, 'same': 247, 'leave': 248, 'other': 249, 'next': 250, 'help': 251, 'customer': 252, 'co': 253, 'x': 254, 'try': 255, 'always': 256, 'tone': 257, 'haha': 258, "you're": 259, 'waiting': 260, 'may': 261, 'few': 262, 'chat': 263, 'heart': 264, 'live': 265, '18': 266, 'even': 267, 'thk': 268, 'soon': 269, 'lunch': 270, 'year': 271, 'class': 272, 'guaranteed': 273, 'y': 274, 'friends': 275, 'wish': 276, 'thought': 277, 'better': 278, "can't": 279, 'cs': 280, 'man': 281, 'things': 282, 'use': 283, 'having': 284, 'meeting': 285, 'done': 286, 'people': 287, '50': 288, 'trying': 289, 'talk': 290, '16': 291, 'ill': 292, 'called': 293, 'real': 294, 'being': 295, 'stuff': 296, '7': 297, 'long': 298, 'person': 299, 'lar': 300, 'mins': 301, 'sir': 302, 'house': 303, 'friend': 304, 'draw': 305, "didn't": 306, 'guess': 307, 'girl': 308, 'bit': 309, 'never': 310, 'special': 311, '6': 312, 'nothing': 313, 'yo': 314, 'shit': 315, 'finish': 316, 'start': 317, 'best': 318, 'because': 319, 'days': 320, 'pl ...

# %%
# pad sequences (to get  N x T matrix)
data_train = pad_sequences(sequences_train)
print('Shape of data train tensor:', data_train.shape)

# N: number of samples and T: Number of time steps
# Out:
# Shape of data train tensor: (3733, 189)

# %%
data_train.shape
# Out:
# (3733, 189)

# %%
data_train
# Out:
# array([[   0,    0,    0, ...,  507,  394,  223],
#        [   0,    0,    0, ...,    5,  294,  224],
#        [   0,    0,    0, ...,    4,  142,  896],
#        ...,
#        [   0,    0,    0, ...,  433, 7139,  695],
#        [   0,    0,    0, ..., 7140,   79, 3339],
#        [   0,    0,    0, ..., 1471, 3389,  436]], dtype=int32)

# %%
# set the value of T to get sequence length
T = data_train.shape[1]

# %%
print(T)
# Out:
# 189

# %%
# pad the test set
data_test = pad_sequences(sequences_test, maxlen=T)
# maxlen = T, to truncate longer sentences in test set
print('Shape of data test tensor:', data_test.shape)
# Out:
# Shape of data test tensor: (1839, 189)

# %% [markdown]
# ## 2. Building the model

# %%
# Create the model

# Choose embedding dimensionality
D = 20  # this is a hyper parameter, we can choose any word vector size that we want

# Input layer
i = Input(shape=(T,))  # input layer takes in sequences of integers, so shape is T

# Embedding layer
x = Embedding(V + 1, D)(i) # This takes in sequences of integers and returns sequences of word vectors
# This will be an N * T * D array
# we want size of embedding to (V + 1) x D, because first word index starts from 1 and not 0

#  First CNN layer
x = Conv1D(32, 3, activation='relu')(x)
x = MaxPooling1D(3)(x)

# Second CNN layer
x = Conv1D(64, 3, activation='relu')(x)
x = MaxPooling1D(3)(x)

# Third CNN layer
x = Conv1D(128, 3, activation='relu')(x)
x = GlobalMaxPooling1D()(x)

# Dense layer
x = Dense(1, activation='sigmoid')(x)

model = Model(i, x)

# %%
# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Train the model
r = model.fit(x=data_train, y=y_train, epochs=5, validation_data=(data_test, y_test))
# Out:
# Epoch 1/5
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 11s 51ms/step - accuracy: 0.8749 - loss: 0.4254 - val_accuracy: 0.9337 - val_loss: 0.1826
# Epoch 2/5
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - accuracy: 0.9547 - loss: 0.1227 - val_accuracy: 0.9799 - val_loss: 0.0651
# Epoch 3/5
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - accuracy: 0.9924 - loss: 0.0218 - val_accuracy: 0.9869 - val_loss: 0.0561
# Epoch 4/5
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - accuracy: 0.9991 - loss: 0.0065 - val_accuracy: 0.9880 - val_loss: 0.0543
# Epoch 5/5
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 6s 49ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.9902 - val_loss: 0.0512

# %%
# Loss per iteration
import matplotlib.pyplot as plt
plt.plot(r.history['loss'], label='Loss')
plt.plot(r.history['val_loss'], label='Validation Loss')
plt.legend()
plt.show()

# %%
# Accuracy per iteration
plt.plot(r.history['accuracy'], label='Accuracy')
plt.plot(r.history['val_accuracy'], label='Validation accuracy')
plt.legend()
plt.show()

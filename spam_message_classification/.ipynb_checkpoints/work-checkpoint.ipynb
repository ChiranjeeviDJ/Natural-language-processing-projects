# %% [markdown]
# # Text classification Spam Detection with RNN

# %% [markdown]
# ## 1. Data Preprocessing

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.18.0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Dense, Input, GlobalMaxPooling1D
from tensorflow.keras.layers import LSTM, Embedding
from tensorflow.keras.models import Model

# %%
df = pd.read_csv('spam.csv', encoding='ISO-8859-1') # encoding needed otherwise error raise, because some varchar exist

# %%
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
# drop garbage columns
df = df.drop(["Unnamed: 2", "Unnamed: 3", "Unnamed: 4"], axis=1)

# %%
df.head()
# Out:
#      v1                                                 v2
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
df.shape
# Out:
# (5572, 2)

# %%
# rename columns
df.columns = ['labels', 'data']

# %%
df.head()
# Out:
#   labels                                               data
# 0    ham  Go until jurong point, crazy.. Available only ...
# 1    ham                      Ok lar... Joking wif u oni...
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3    ham  U dun say so early hor... U c already then say...
# 4    ham  Nah I don't think he goes to usf, he lives aro...

# %%
# create binary labels (0 and 1)
df['b_labels'] = df['labels'].map({'ham': 0, 'spam': 1}) # create new column as 'b_labels'
y = df['b_labels'].values

# %%
y
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %%
df
# Out:
#      labels                                               data  b_labels
# 0       ham  Go until jurong point, crazy.. Available only ...         0
# 1       ham                      Ok lar... Joking wif u oni...         0
# 2      spam  Free entry in 2 a wkly comp to win FA Cup fina...         1
# 3       ham  U dun say so early hor... U c already then say...         0
# 4       ham  Nah I don't think he goes to usf, he lives aro...         0
# ...     ...                                                ...       ...
# 5567   spam  This is the 2nd time we have tried 2 contact u...         1
# 5568    ham              Will Ì_ b going to esplanade fr home?         0
# 5569    ham  Pity, * was in mood for that. So...any other s...         0
# 5570    ham  The guy did some bitching but I acted like i'd...         0
# 5571    ham                         Rofl. Its true to its name         0
#
# [5572 rows x 3 columns]

# %%
# split the data
x_train, x_test, y_train, y_test = train_test_split(df['data'], y, test_size=0.33)

# %%
# Convert sentences to sequences
max_vocab_size = 20000
tokenizer = Tokenizer(num_words=max_vocab_size)
tokenizer.fit_on_texts(x_train)
sequences_train = tokenizer.texts_to_sequences(x_train)
sequences_test = tokenizer.texts_to_sequences(x_test)

# %%
x_train
# Out:
# 1754    How is your schedule next week? I am out of to...
# 12      URGENT! You have won a 1 week FREE membership ...
# 2208    URGENT!! Your 4* Costa Del Sol Holiday or å£50...
# 3963                If e timing can, then i go w u lor...
# 5115    Get 3 Lions England tone, reply lionm 4 mono o...
#                               ...
# 783     You have an important customer service announc...
# 4003    Well there's a pattern emerging of my friends ...
# 4870                  Well. You know what i mean. Texting
# 2031    I noe la... U wana pei bf oso rite... K lor, o...
# 3402         Good night my dear.. Sleepwell&amp;Take care
# Name: data, Length: 3733, dtype: object

# %%
sequences_train[0]
# Out:
# [49, 9, 12, 1805, 231, 125, 1, 59, 52, 15, 465, 41, 388]

# %%
len(sequences_train[0])
# Out:
# 13

# %%
len(sequences_train[1])
# Out:
# 30

# %%
# Check word index mapping (to check the number of words in vocabulary)
word2idx = tokenizer.word_index
V = len(word2idx)
print('Total number of unique tokens are: %s' % V)
# Out:
# Total number of unique tokens are: 7326

# %%
print(word2idx)
# Out:
# {'i': 1, 'to': 2, 'you': 3, 'a': 4, 'the': 5, 'u': 6, 'and': 7, 'in': 8, 'is': 9, 'me': 10, 'my': 11, 'your': 12, 'for': 13, 'it': 14, 'of': 15, 'have': 16, 'call': 17, 'on': 18, '2': 19, 'are': 20, 'now': 21, 'that': 22, 'so': 23, 'but': 24, 'or': 25, 'can': 26, 'do': 27, 'get': 28, 'at': 29, 'ur': 30, "i'm": 31, 'will': 32, 'not': 33, 'no': 34, 'be': 35, 'if': 36, 'we': 37, 'just': 38, 'with': 39, '4': 40, 'this': 41, 'up': 42, 'gt': 43, 'lt': 44, 'ok': 45, 'from': 46, 'go': 47, 'when': 48, 'how': 49, 'free': 50, 'all': 51, 'out': 52, 'what': 53, 'know': 54, 'was': 55, 'like': 56, 'got': 57, 'good': 58, 'am': 59, 'come': 60, 'only': 61, 'then': 62, 'day': 63, '
': 287, 'yet': 288, 'days': 289, 'bit': 290, 'may': 291, 'done': 292, 'problem': 293, 'cs': 294, 'y': 295, 'mind': 296, 'name': 297, 'shows': 298, 'thought': 299, 'guess': 300, 'awarded': 301, 'landline': 302, 'line': 303, '150ppm': 304, 'wk': 305, "didn't": 306, 'year': 307, 'mins': 308, 'job': 309, 'word': 310, 'special': 311, 'thats': 312, 'wanna': 313, 'ready': 314, '6': 315, 'half': 316, 'trying': 317, 'same': 318, 'dat': 319, 'class': 320, 'sm ...

# %%
# pad sequences (to get  N x T matrix)
data_train = pad_sequences(sequences_train)
print('Shape of data train tensor:', data_train.shape)

# N: number of samples and T: Number of time steps
# Out:
# Shape of data train tensor: (3733, 189)

# %%
data_train.shape
# Out:
# (3733, 189)

# %%
data_train
# Out:
# array([[   0,    0,    0, ...,  465,   41,  388],
#        [   0,    0,    0, ..., 2311,  614, 2312],
#        [   0,    0,    0, ...,  251,  615, 1120],
#        ...,
#        [   0,    0,    0, ...,    1,  558, 2876],
#        [   0,    0,    0, ...,  243,  289,  365],
#        [   0,    0,    0, ...,  155,   84,  204]], dtype=int32)

# %%
# set the value of T to get sequence length
T = data_train.shape[1]

# %%
print(T)
# Out:
# 189

# %%
# pad the test set
data_test = pad_sequences(sequences_test, maxlen=T)
# maxlen = T, to truncate longer sentences in test set
print('Shape of data test tensor:', data_test.shape)
# Out:
# Shape of data test tensor: (1839, 189)

# %% [markdown]
# ## 2. Building the model

# %%
# Choose embedding dimensionality
D = 20  # this is a hyper parameter, we can choose any word vector size that we want

# Hidden state vectorsize (dimensionality)
M = 15

# Input layer
i = Input(shape=(T,))  # input layer takes in sequences of integers, so shape is T

# Embedding layer
x = Embedding(V + 1, D)(i) # This takes in sequences of integers and returns sequences of word vectors
# This will be an N * T * D array
# we want size of embedding to (V + 1) x D, because first word index starts from 1 and not 0

# LSTM layer
x = LSTM(M, return_sequences=True)(x)
x = GlobalMaxPooling1D()(x)

# Dense layer
x = Dense(1, activation='sigmoid')(x)
# it is an binary classification problem, so we are using activation function ='sigmoid'

model = Model(i, x)

# %%
# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Train the model
r = model.fit(x=data_train, y=y_train, epochs=10, validation_data=(data_test, y_test))
# Out:
# Epoch 1/10
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - accuracy: 0.8634 - loss: 0.4932 - val_accuracy: 0.8766 - val_loss: 0.3112
# Epoch 2/10
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - accuracy: 0.8820 - loss: 0.2657 - val_accuracy: 0.9815 - val_loss: 0.1191
# Epoch 3/10
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.9880 - loss: 0.1006 - val_accuracy: 0.9875 - val_loss: 0.0750
# Epoch 4/10
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.9906 - loss: 0.0598 - val_accuracy: 0.9880 - val_loss: 0.0604
# Epoch 5/10
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.9947 - loss: 0.0396 - val_accuracy: 0.9908 - val_loss: 0.0487
# Epoch 6/10
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.9981 - loss: 0.0242 - val_accuracy: 0.9908 - val_loss: 0.0445
# Epoch 7/10
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.9984 - loss: 0.0191 - val_accuracy: 0.9891 - val_loss: 0.0450
# Epoch 8/10
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.9993 - loss: 0.0126 - val_accuracy: 0.9924 - val_loss: 0.0393
# Epoch 9/10
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 6s 49ms/step - accuracy: 0.9996 - loss: 0.0103 - val_accuracy: 0.9902 - val_loss: 0.0446
# Epoch 10/10
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - accuracy: 0.9992 - loss: 0.0103 - val_accuracy: 0.9924 - val_loss: 0.0366

# %%
# Loss per iteration
import matplotlib.pyplot as plt
plt.plot(r.history['loss'], label='Loss')
plt.plot(r.history['val_loss'], label='Validation Loss')
plt.legend()
plt.show()

# %%
# Accuracy per iteration
plt.plot(r.history['accuracy'], label='Accuracy')
plt.plot(r.history['val_accuracy'], label='Validation accuracy')
plt.legend()
plt.show()
